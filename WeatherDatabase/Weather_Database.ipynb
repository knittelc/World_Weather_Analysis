# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 754

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval        ")
print("--------------------------------")

# Create counters

record_count = 1
set_count =1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 1 | san patricio
# Processing Record 4 of Set 1 | kapaa
# Processing Record 5 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 6 of Set 1 | almansa
# Processing Record 7 of Set 1 | bathsheba
# Processing Record 8 of Set 1 | dudinka
# Processing Record 9 of Set 1 | laramie
# Processing Record 10 of Set 1 | xichang
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | tasiilaq
# Processing Record 13 of Set 1 | victoria
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | touros
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | chokurdakh
# Processing Record 18 of Set 1 | lazarev
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | chhabra
# Processing Record 22 of Set 1 | annau
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | ponta do sol
# Processing Record 25 of Set 1 | bredasdorp
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | los llanos de aridane
# Processing Record 29 of Set 1 | talant
# Processing Record 30 of Set 1 | natal
# Processing Record 31 of Set 1 | atuona
# Processing Record 32 of Set 1 | orlik
# Processing Record 33 of Set 1 | sao filipe
# Processing Record 34 of Set 1 | salalah
# Processing Record 35 of Set 1 | road town
# Processing Record 36 of Set 1 | tooele
# Processing Record 37 of Set 1 | ixtapa
# Processing Record 38 of Set 1 | bechem
# Processing Record 39 of Set 1 | melfi
# Processing Record 40 of Set 1 | luwuk
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | gravdal
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 1 | samarai
# Processing Record 46 of Set 1 | raga
# Processing Record 47 of Set 1 | cortez
# Processing Record 48 of Set 1 | sao joao da barra
# Processing Record 49 of Set 1 | puerto ayora
# Processing Record 50 of Set 1 | alofi
# Processing Record 1 of Set 2 | jumla
# Processing Record 2 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 2 | thompson
# Processing Record 4 of Set 2 | kodiak
# Processing Record 5 of Set 2 | bambous virieux
# Processing Record 6 of Set 2 | goderich
# Processing Record 7 of Set 2 | iqaluit
# Processing Record 8 of Set 2 | yellowknife
# Processing Record 9 of Set 2 | hasaki
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | luganville
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | odienne
# Processing Record 14 of Set 2 | grand gaube
# Processing Record 15 of Set 2 | rio de janeiro
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | taoudenni
# Processing Record 18 of Set 2 | castro
# Processing Record 19 of Set 2 | tual
# Processing Record 20 of Set 2 | shinichi
# Processing Record 21 of Set 2 | arinos
# Processing Record 22 of Set 2 | bluff
# Processing Record 23 of Set 2 | mehamn
# Processing Record 24 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 25 of Set 2 | provideniya
# Processing Record 26 of Set 2 | baillif
# Processing Record 27 of Set 2 | alboraya
# Processing Record 28 of Set 2 | sao gabriel da cachoeira
# Processing Record 29 of Set 2 | georgetown
# Processing Record 30 of Set 2 | centenario do sul
# Processing Record 31 of Set 2 | we
# City not found. Skipping...
# Processing Record 32 of Set 2 | trelew
# Processing Record 33 of Set 2 | adrar
# Processing Record 34 of Set 2 | kushima
# Processing Record 35 of Set 2 | puerto colombia
# Processing Record 36 of Set 2 | san carlos de bariloche
# Processing Record 37 of Set 2 | constitucion
# Processing Record 38 of Set 2 | hobart
# Processing Record 39 of Set 2 | tuktoyaktuk
# Processing Record 40 of Set 2 | cidreira
# Processing Record 41 of Set 2 | hoa binh
# Processing Record 42 of Set 2 | hammerfest
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | luderitz
# Processing Record 45 of Set 2 | salamiyah
# Processing Record 46 of Set 2 | ushtobe
# Processing Record 47 of Set 2 | mirnyy
# Processing Record 48 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 2 | curup
# Processing Record 50 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 3 | cabo san lucas
# Processing Record 2 of Set 3 | puerto del rosario
# Processing Record 3 of Set 3 | freeport
# Processing Record 4 of Set 3 | laguna
# Processing Record 5 of Set 3 | serebryansk
# Processing Record 6 of Set 3 | hilo
# Processing Record 7 of Set 3 | port alfred
# Processing Record 8 of Set 3 | saint george
# Processing Record 9 of Set 3 | vestmannaeyjar
# Processing Record 10 of Set 3 | fort nelson
# Processing Record 11 of Set 3 | aksu
# Processing Record 12 of Set 3 | ribeira grande
# Processing Record 13 of Set 3 | worland
# Processing Record 14 of Set 3 | avarua
# Processing Record 15 of Set 3 | arlit
# Processing Record 16 of Set 3 | tiksi
# Processing Record 17 of Set 3 | broome
# Processing Record 18 of Set 3 | leh
# Processing Record 19 of Set 3 | saint-philippe
# Processing Record 20 of Set 3 | iquique
# Processing Record 21 of Set 3 | deputatskiy
# Processing Record 22 of Set 3 | vialonga
# Processing Record 23 of Set 3 | mercedes
# Processing Record 24 of Set 3 | saint anthony
# Processing Record 25 of Set 3 | qeshm
# Processing Record 26 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 27 of Set 3 | wichita
# Processing Record 28 of Set 3 | vallenar
# Processing Record 29 of Set 3 | taunggyi
# Processing Record 30 of Set 3 | bengkulu
# Processing Record 31 of Set 3 | kavieng
# Processing Record 32 of Set 3 | baykit
# Processing Record 33 of Set 3 | lompoc
# Processing Record 34 of Set 3 | pacific grove
# Processing Record 35 of Set 3 | enid
# Processing Record 36 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 3 | norman wells
# Processing Record 38 of Set 3 | chernyshevskiy
# Processing Record 39 of Set 3 | xining
# Processing Record 40 of Set 3 | aykhal
# Processing Record 41 of Set 3 | lilienthal
# Processing Record 42 of Set 3 | kahului
# Processing Record 43 of Set 3 | ancud
# Processing Record 44 of Set 3 | aljezur
# Processing Record 45 of Set 3 | guerrero negro
# Processing Record 46 of Set 3 | uray
# Processing Record 47 of Set 3 | severo-kurilsk
# Processing Record 48 of Set 3 | la rochelle
# Processing Record 49 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 3 | beringovskiy
# Processing Record 1 of Set 4 | aswan
# Processing Record 2 of Set 4 | dhrangadhra
# Processing Record 3 of Set 4 | east london
# Processing Record 4 of Set 4 | te anau
# Processing Record 5 of Set 4 | srandakan
# Processing Record 6 of Set 4 | udachnyy
# Processing Record 7 of Set 4 | divnomorskoye
# Processing Record 8 of Set 4 | nicoya
# Processing Record 9 of Set 4 | shenjiamen
# Processing Record 10 of Set 4 | beyneu
# Processing Record 11 of Set 4 | nata
# Processing Record 12 of Set 4 | strezhevoy
# Processing Record 13 of Set 4 | lavrentiya
# Processing Record 14 of Set 4 | sitka
# Processing Record 15 of Set 4 | henties bay
# Processing Record 16 of Set 4 | sola
# Processing Record 17 of Set 4 | karratha
# Processing Record 18 of Set 4 | salmon arm
# Processing Record 19 of Set 4 | hounde
# Processing Record 20 of Set 4 | alekseyevka
# Processing Record 21 of Set 4 | tuggurt
# City not found. Skipping...
# Processing Record 22 of Set 4 | port lincoln
# Processing Record 23 of Set 4 | isangel
# Processing Record 24 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 26 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 4 | vardo
# Processing Record 28 of Set 4 | patiya
# Processing Record 29 of Set 4 | honningsvag
# Processing Record 30 of Set 4 | baryshivka
# Processing Record 31 of Set 4 | pevek
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | ayan
# Processing Record 34 of Set 4 | narsaq
# Processing Record 35 of Set 4 | balkanabat
# Processing Record 36 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 4 | rosarito
# Processing Record 38 of Set 4 | bin qirdan
# Processing Record 39 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 4 | bethel
# Processing Record 41 of Set 4 | tura
# Processing Record 42 of Set 4 | chuy
# Processing Record 43 of Set 4 | warsaw
# Processing Record 44 of Set 4 | clyde river
# Processing Record 45 of Set 4 | kentwood
# Processing Record 46 of Set 4 | auch
# Processing Record 47 of Set 4 | napanee
# Processing Record 48 of Set 4 | chifeng
# Processing Record 49 of Set 4 | havre-saint-pierre
# Processing Record 50 of Set 4 | carnarvon
# Processing Record 1 of Set 5 | dikson
# Processing Record 2 of Set 5 | atyrau
# Processing Record 3 of Set 5 | lemesos
# City not found. Skipping...
# Processing Record 4 of Set 5 | qaqortoq
# Processing Record 5 of Set 5 | nenjiang
# Processing Record 6 of Set 5 | mehndawal
# Processing Record 7 of Set 5 | butembo
# Processing Record 8 of Set 5 | port elizabeth
# Processing Record 9 of Set 5 | torbay
# Processing Record 10 of Set 5 | coihaique
# Processing Record 11 of Set 5 | nha trang
# Processing Record 12 of Set 5 | jiuquan
# Processing Record 13 of Set 5 | vestmanna
# Processing Record 14 of Set 5 | nove mesto na morave
# Processing Record 15 of Set 5 | esperance
# Processing Record 16 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 5 | saskylakh
# Processing Record 18 of Set 5 | manaus
# Processing Record 19 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 5 | mahebourg
# Processing Record 21 of Set 5 | peniche
# Processing Record 22 of Set 5 | rafaela
# Processing Record 23 of Set 5 | wundanyi
# Processing Record 24 of Set 5 | airai
# Processing Record 25 of Set 5 | opobo
# City not found. Skipping...
# Processing Record 26 of Set 5 | caravelas
# Processing Record 27 of Set 5 | formosa do rio preto
# Processing Record 28 of Set 5 | vostok
# Processing Record 29 of Set 5 | khatanga
# Processing Record 30 of Set 5 | warwick
# Processing Record 31 of Set 5 | gizo
# Processing Record 32 of Set 5 | batagay
# Processing Record 33 of Set 5 | barth
# Processing Record 34 of Set 5 | college
# Processing Record 35 of Set 5 | la ronge
# Processing Record 36 of Set 5 | niquelandia
# Processing Record 37 of Set 5 | ostrovnoy
# Processing Record 38 of Set 5 | kalmunai
# Processing Record 39 of Set 5 | alice springs
# Processing Record 40 of Set 5 | pisco
# Processing Record 41 of Set 5 | columbia
# Processing Record 42 of Set 5 | mitsamiouli
# Processing Record 43 of Set 5 | grafton
# Processing Record 44 of Set 5 | escuinapa
# Processing Record 45 of Set 5 | ilulissat
# Processing Record 46 of Set 5 | vila franca do campo
# Processing Record 47 of Set 5 | pilot butte
# Processing Record 48 of Set 5 | komsomolskiy
# Processing Record 49 of Set 5 | saldanha
# Processing Record 50 of Set 5 | sorkjosen
# Processing Record 1 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 2 of Set 6 | malinyi
# Processing Record 3 of Set 6 | terrak
# Processing Record 4 of Set 6 | basoko
# Processing Record 5 of Set 6 | cape town
# Processing Record 6 of Set 6 | mascote
# Processing Record 7 of Set 6 | barcelos
# Processing Record 8 of Set 6 | qaanaaq
# Processing Record 9 of Set 6 | aklavik
# Processing Record 10 of Set 6 | zhigansk
# Processing Record 11 of Set 6 | halmstad
# Processing Record 12 of Set 6 | pangnirtung
# Processing Record 13 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 6 | shingu
# Processing Record 15 of Set 6 | kaitangata
# Processing Record 16 of Set 6 | conde
# Processing Record 17 of Set 6 | zabid
# Processing Record 18 of Set 6 | upernavik
# Processing Record 19 of Set 6 | hofn
# Processing Record 20 of Set 6 | yinchuan
# Processing Record 21 of Set 6 | yar-sale
# Processing Record 22 of Set 6 | sigli
# Processing Record 23 of Set 6 | bowen
# Processing Record 24 of Set 6 | labuhan
# Processing Record 25 of Set 6 | yafran
# Processing Record 26 of Set 6 | qandahar
# City not found. Skipping...
# Processing Record 27 of Set 6 | springbok
# Processing Record 28 of Set 6 | trebukhiv
# Processing Record 29 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 6 | korla
# Processing Record 31 of Set 6 | mitchell
# Processing Record 32 of Set 6 | umm lajj
# Processing Record 33 of Set 6 | prabumulih
# Processing Record 34 of Set 6 | sosnogorsk
# Processing Record 35 of Set 6 | barra patuca
# Processing Record 36 of Set 6 | parry sound
# Processing Record 37 of Set 6 | fort saint james
# Processing Record 38 of Set 6 | fredericksburg
# Processing Record 39 of Set 6 | zhangjiakou
# Processing Record 40 of Set 6 | ulladulla
# Processing Record 41 of Set 6 | koppies
# Processing Record 42 of Set 6 | maputo
# Processing Record 43 of Set 6 | katsuura
# Processing Record 44 of Set 6 | mooi river
# City not found. Skipping...
# Processing Record 45 of Set 6 | krasnoarmeysk
# Processing Record 46 of Set 6 | kuryk
# Processing Record 47 of Set 6 | lake havasu city
# Processing Record 48 of Set 6 | charters towers
# Processing Record 49 of Set 6 | glubokoe
# City not found. Skipping...
# Processing Record 50 of Set 6 | geraldton
# Processing Record 1 of Set 7 | abonnema
# Processing Record 2 of Set 7 | kizilskoye
# Processing Record 3 of Set 7 | popondetta
# Processing Record 4 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 5 of Set 7 | ternate
# Processing Record 6 of Set 7 | zabolottya
# City not found. Skipping...
# Processing Record 7 of Set 7 | namibe
# Processing Record 8 of Set 7 | lebu
# Processing Record 9 of Set 7 | sabara
# Processing Record 10 of Set 7 | bidar
# Processing Record 11 of Set 7 | new norfolk
# Processing Record 12 of Set 7 | serebryanyy bor
# Processing Record 13 of Set 7 | sorland
# Processing Record 14 of Set 7 | nome
# Processing Record 15 of Set 7 | manzanillo
# Processing Record 16 of Set 7 | ajdabiya
# Processing Record 17 of Set 7 | ciudad bolivar
# Processing Record 18 of Set 7 | hay river
# Processing Record 19 of Set 7 | diego de almagro
# Processing Record 20 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 7 | jiaojiang
# Processing Record 22 of Set 7 | tautira
# Processing Record 23 of Set 7 | port hedland
# Processing Record 24 of Set 7 | port hardy
# Processing Record 25 of Set 7 | kruisfontein
# Processing Record 26 of Set 7 | port hueneme
# Processing Record 27 of Set 7 | alugan
# Processing Record 28 of Set 7 | leningradskiy
# Processing Record 29 of Set 7 | faanui
# Processing Record 30 of Set 7 | lauenburg
# Processing Record 31 of Set 7 | quatre cocos
# Processing Record 32 of Set 7 | talnakh
# Processing Record 33 of Set 7 | khatassy
# Processing Record 34 of Set 7 | sao felix do xingu
# Processing Record 35 of Set 7 | narowal
# Processing Record 36 of Set 7 | dogondoutchi
# Processing Record 37 of Set 7 | fukue
# Processing Record 38 of Set 7 | verkhoyansk
# Processing Record 39 of Set 7 | fortuna
# Processing Record 40 of Set 7 | terre-de-bas
# Processing Record 41 of Set 7 | tuatapere
# Processing Record 42 of Set 7 | sangar
# Processing Record 43 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 44 of Set 7 | veraval
# Processing Record 45 of Set 7 | vila velha
# Processing Record 46 of Set 7 | dunedin
# Processing Record 47 of Set 7 | nador
# Processing Record 48 of Set 7 | beloha
# Processing Record 49 of Set 7 | tres arroyos
# Processing Record 50 of Set 7 | nikolskoye
# Processing Record 1 of Set 8 | mandalgovi
# Processing Record 2 of Set 8 | yarmouth
# Processing Record 3 of Set 8 | lakes entrance
# Processing Record 4 of Set 8 | ozernovskiy
# Processing Record 5 of Set 8 | basco
# Processing Record 6 of Set 8 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 8 | bayamo
# Processing Record 8 of Set 8 | dolinsk
# Processing Record 9 of Set 8 | bara
# Processing Record 10 of Set 8 | kazachinskoye
# Processing Record 11 of Set 8 | klaksvik
# Processing Record 12 of Set 8 | lorengau
# Processing Record 13 of Set 8 | banda aceh
# Processing Record 14 of Set 8 | roald
# Processing Record 15 of Set 8 | phalombe
# Processing Record 16 of Set 8 | vega de alatorre
# Processing Record 17 of Set 8 | sechura
# Processing Record 18 of Set 8 | sambava
# Processing Record 19 of Set 8 | pastavy
# Processing Record 20 of Set 8 | saint-francois
# Processing Record 21 of Set 8 | mopipi
# Processing Record 22 of Set 8 | finschhafen
# Processing Record 23 of Set 8 | longyearbyen
# Processing Record 24 of Set 8 | rundu
# Processing Record 25 of Set 8 | roma
# Processing Record 26 of Set 8 | pasni
# Processing Record 27 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 8 | baghdad
# Processing Record 29 of Set 8 | sataua
# City not found. Skipping...
# Processing Record 30 of Set 8 | isiro
# Processing Record 31 of Set 8 | santa clarita
# Processing Record 32 of Set 8 | san juan
# Processing Record 33 of Set 8 | yabelo
# Processing Record 34 of Set 8 | souillac
# Processing Record 35 of Set 8 | cayenne
# Processing Record 36 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 8 | nizwa
# Processing Record 38 of Set 8 | mildura
# Processing Record 39 of Set 8 | agadir
# Processing Record 40 of Set 8 | mayumba
# Processing Record 41 of Set 8 | portland
# Processing Record 42 of Set 8 | kharp
# Processing Record 43 of Set 8 | chimoio
# Processing Record 44 of Set 8 | puksoozero
# Processing Record 45 of Set 8 | rypefjord
# Processing Record 46 of Set 8 | olanchito
# Processing Record 47 of Set 8 | lowestoft
# Processing Record 48 of Set 8 | namatanai
# Processing Record 49 of Set 8 | panaba
# Processing Record 50 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 9 | mackenzie
# Processing Record 2 of Set 9 | daru
# Processing Record 3 of Set 9 | bestobe
# Processing Record 4 of Set 9 | grindavik
# Processing Record 5 of Set 9 | innoshima
# Processing Record 6 of Set 9 | valdivia
# Processing Record 7 of Set 9 | derzhavinsk
# Processing Record 8 of Set 9 | saint-pierre
# Processing Record 9 of Set 9 | sept-iles
# Processing Record 10 of Set 9 | sao paulo de olivenca
# Processing Record 11 of Set 9 | anadyr
# Processing Record 12 of Set 9 | thohoyandou
# Processing Record 13 of Set 9 | abatskoye
# Processing Record 14 of Set 9 | matagami
# Processing Record 15 of Set 9 | kupang
# Processing Record 16 of Set 9 | riyadh
# Processing Record 17 of Set 9 | lagoa
# Processing Record 18 of Set 9 | egvekinot
# Processing Record 19 of Set 9 | novoselytsya
# Processing Record 20 of Set 9 | la riviera
# Processing Record 21 of Set 9 | bakchar
# Processing Record 22 of Set 9 | malartic
# Processing Record 23 of Set 9 | lepe
# Processing Record 24 of Set 9 | rorvik
# Processing Record 25 of Set 9 | mazamari
# Processing Record 26 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 9 | leshukonskoye
# Processing Record 28 of Set 9 | opuwo
# Processing Record 29 of Set 9 | dingle
# Processing Record 30 of Set 9 | urumqi
# Processing Record 31 of Set 9 | izhma
# Processing Record 32 of Set 9 | chicama
# Processing Record 33 of Set 9 | sabancuy
# Processing Record 34 of Set 9 | wanaka
# Processing Record 35 of Set 9 | carmen
# Processing Record 36 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 9 | asau
# Processing Record 40 of Set 9 | bonthe
# Processing Record 41 of Set 9 | muzhi
# Processing Record 42 of Set 9 | aracaju
# Processing Record 43 of Set 9 | smithers
# Processing Record 44 of Set 9 | luangwa
# Processing Record 45 of Set 9 | yerbogachen
# Processing Record 46 of Set 9 | anse-bertrand
# Processing Record 47 of Set 9 | kashi
# Processing Record 48 of Set 9 | auki
# Processing Record 49 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 50 of Set 9 | necochea
# Processing Record 1 of Set 10 | kalabo
# Processing Record 2 of Set 10 | malakal
# Processing Record 3 of Set 10 | tongliao
# Processing Record 4 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 10 | redlands
# Processing Record 6 of Set 10 | harij
# Processing Record 7 of Set 10 | kenai
# Processing Record 8 of Set 10 | kysyl-syr
# Processing Record 9 of Set 10 | along
# Processing Record 10 of Set 10 | kant
# Processing Record 11 of Set 10 | port blair
# Processing Record 12 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 10 | yumen
# Processing Record 14 of Set 10 | san cristobal
# Processing Record 15 of Set 10 | de-kastri
# Processing Record 16 of Set 10 | gasa
# Processing Record 17 of Set 10 | kavaratti
# Processing Record 18 of Set 10 | camana
# Processing Record 19 of Set 10 | savinka
# Processing Record 20 of Set 10 | tilichiki
# Processing Record 21 of Set 10 | carballo
# Processing Record 22 of Set 10 | mamallapuram
# Processing Record 23 of Set 10 | huazolotitlan
# City not found. Skipping...
# Processing Record 24 of Set 10 | sakakah
# Processing Record 25 of Set 10 | sale
# Processing Record 26 of Set 10 | saucillo
# Processing Record 27 of Set 10 | golden
# Processing Record 28 of Set 10 | dutse
# Processing Record 29 of Set 10 | ntchisi
# Processing Record 30 of Set 10 | umm kaddadah
# Processing Record 31 of Set 10 | flinders
# Processing Record 32 of Set 10 | tupelo
# Processing Record 33 of Set 10 | sistranda
# Processing Record 34 of Set 10 | asamankese
# Processing Record 35 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 36 of Set 10 | antalaha
# Processing Record 37 of Set 10 | mahajanga
# Processing Record 38 of Set 10 | bereda
# Processing Record 39 of Set 10 | sioux lookout
# Processing Record 40 of Set 10 | yulara
# Processing Record 41 of Set 10 | rincon
# Processing Record 42 of Set 10 | mount isa
# Processing Record 43 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 10 | jiayuguan
# Processing Record 45 of Set 10 | fairbanks
# Processing Record 46 of Set 10 | saint-joseph
# Processing Record 47 of Set 10 | kurchum
# Processing Record 48 of Set 10 | westport
# Processing Record 49 of Set 10 | xam nua
# Processing Record 50 of Set 10 | alta floresta
# Processing Record 1 of Set 11 | hualmay
# Processing Record 2 of Set 11 | lagos
# Processing Record 3 of Set 11 | parthenay
# Processing Record 4 of Set 11 | mosquera
# Processing Record 5 of Set 11 | kingman
# Processing Record 6 of Set 11 | aksarka
# Processing Record 7 of Set 11 | cam ranh
# Processing Record 8 of Set 11 | sourpi
# Processing Record 9 of Set 11 | totness
# Processing Record 10 of Set 11 | steinbach
# Processing Record 11 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 12 of Set 11 | honiara
# Processing Record 13 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 14 of Set 11 | oktyabrskiy
# Processing Record 15 of Set 11 | agirish
# Processing Record 16 of Set 11 | dwarka
# Processing Record 17 of Set 11 | maniitsoq
# Processing Record 18 of Set 11 | viking
# Processing Record 19 of Set 11 | talara
# Processing Record 20 of Set 11 | waingapu
# Processing Record 21 of Set 11 | phangnga
# Processing Record 22 of Set 11 | yabrud
# Processing Record 23 of Set 11 | hokitika
# Processing Record 24 of Set 11 | yaan
# Processing Record 25 of Set 11 | hays
# Processing Record 26 of Set 11 | saint-georges
# Processing Record 27 of Set 11 | eidfjord
# Processing Record 28 of Set 11 | sofiysk
# City not found. Skipping...
# Processing Record 29 of Set 11 | halifax
# Processing Record 30 of Set 11 | doba
# Processing Record 31 of Set 11 | omboue
# Processing Record 32 of Set 11 | oud-beijerland
# Processing Record 33 of Set 11 | turtkul
# City not found. Skipping...
# Processing Record 34 of Set 11 | bichura
# Processing Record 35 of Set 11 | marsa matruh
# Processing Record 36 of Set 11 | pakwach
# City not found. Skipping...
# Processing Record 37 of Set 11 | hovd
# Processing Record 38 of Set 11 | glasgow
# Processing Record 39 of Set 11 | nanortalik
# Processing Record 40 of Set 11 | wau
# Processing Record 41 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 42 of Set 11 | teguldet
# Processing Record 43 of Set 11 | ust-karsk
# Processing Record 44 of Set 11 | nanakuli
# Processing Record 45 of Set 11 | urk
# Processing Record 46 of Set 11 | kaniama
# Processing Record 47 of Set 11 | aldergrove
# Processing Record 48 of Set 11 | zelenyy bor
# Processing Record 49 of Set 11 | conceicao do araguaia
# Processing Record 50 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 12 | salair
# Processing Record 2 of Set 12 | gweta
# Processing Record 3 of Set 12 | adra
# Processing Record 4 of Set 12 | richards bay
# Processing Record 5 of Set 12 | jaisalmer
# Processing Record 6 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 7 of Set 12 | west wendover
# Processing Record 8 of Set 12 | sheridan
# Processing Record 9 of Set 12 | uyuni
# Processing Record 10 of Set 12 | coahuayana
# Processing Record 11 of Set 12 | mufulira
# Processing Record 12 of Set 12 | bambanglipuro
# Processing Record 13 of Set 12 | ouesso
# Processing Record 14 of Set 12 | pavlovsk
# Processing Record 15 of Set 12 | kyren
# Processing Record 16 of Set 12 | rudnogorsk
# Processing Record 17 of Set 12 | nioro
# Processing Record 18 of Set 12 | bria
# Processing Record 19 of Set 12 | vila
# Processing Record 20 of Set 12 | tanggu
# Processing Record 21 of Set 12 | bilibino
# Processing Record 22 of Set 12 | kedrovyy
# Processing Record 23 of Set 12 | chapais
# Processing Record 24 of Set 12 | krasnoselkup
# Processing Record 25 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 26 of Set 12 | bani
# Processing Record 27 of Set 12 | preeceville
# Processing Record 28 of Set 12 | saint-augustin
# Processing Record 29 of Set 12 | makat
# Processing Record 30 of Set 12 | suntar
# Processing Record 31 of Set 12 | seoul
# Processing Record 32 of Set 12 | arman
# Processing Record 33 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 12 | norden
# Processing Record 35 of Set 12 | tiznit
# Processing Record 36 of Set 12 | tomatlan
# Processing Record 37 of Set 12 | chishtian mandi
# Processing Record 38 of Set 12 | luanda
# Processing Record 39 of Set 12 | heide
# Processing Record 40 of Set 12 | dakar
# Processing Record 41 of Set 12 | havoysund
# Processing Record 42 of Set 12 | paamiut
# Processing Record 43 of Set 12 | cherskiy
# Processing Record 44 of Set 12 | ndioum
# Processing Record 45 of Set 12 | bristol
# Processing Record 46 of Set 12 | celestun
# Processing Record 47 of Set 12 | ha giang
# Processing Record 48 of Set 12 | nemyriv
# Processing Record 49 of Set 12 | show low
# Processing Record 50 of Set 12 | sjenica
# Processing Record 1 of Set 13 | kushmurun
# Processing Record 2 of Set 13 | soyo
# Processing Record 3 of Set 13 | aberdeen
# Processing Record 4 of Set 13 | gat
# Processing Record 5 of Set 13 | amahai
# Processing Record 6 of Set 13 | bandarbeyla
# Processing Record 7 of Set 13 | iracoubo
# Processing Record 8 of Set 13 | mapiri
# Processing Record 9 of Set 13 | sawtell
# Processing Record 10 of Set 13 | aizkraukle
# Processing Record 11 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 12 of Set 13 | hervey bay
# Processing Record 13 of Set 13 | la cruz
# Processing Record 14 of Set 13 | shitkino
# Processing Record 15 of Set 13 | anloga
# Processing Record 16 of Set 13 | tuensang
# Processing Record 17 of Set 13 | wapakoneta
# Processing Record 18 of Set 13 | nabire
# Processing Record 19 of Set 13 | faya
# Processing Record 20 of Set 13 | san quintin
# Processing Record 21 of Set 13 | marawi
# Processing Record 22 of Set 13 | tevriz
# Processing Record 23 of Set 13 | sirsi
# Processing Record 24 of Set 13 | parnamirim
# Processing Record 25 of Set 13 | eatonton
# Processing Record 26 of Set 13 | belaya gora
# Processing Record 27 of Set 13 | dalvik
# Processing Record 28 of Set 13 | coquimbo
# Processing Record 29 of Set 13 | comodoro rivadavia
# Processing Record 30 of Set 13 | banes
# Processing Record 31 of Set 13 | wa
# City not found. Skipping...
# Processing Record 32 of Set 13 | ketchikan
# Processing Record 33 of Set 13 | limbazi
# Processing Record 34 of Set 13 | denizli
# Processing Record 35 of Set 13 | kilindoni
# Processing Record 36 of Set 13 | batagay-alyta
# Processing Record 37 of Set 13 | la asuncion
# Processing Record 38 of Set 13 | sebezh
# Processing Record 39 of Set 13 | shaoyang
# Processing Record 40 of Set 13 | samarina
# Processing Record 41 of Set 13 | tutoia
# Processing Record 42 of Set 13 | san luis
# Processing Record 43 of Set 13 | teguise
# Processing Record 44 of Set 13 | buchanan
# Processing Record 45 of Set 13 | mandawar
# Processing Record 46 of Set 13 | narasannapeta
# Processing Record 47 of Set 13 | lieksa
# Processing Record 48 of Set 13 | kismayo
# Processing Record 49 of Set 13 | avera
# Processing Record 50 of Set 13 | berlevag
# Processing Record 1 of Set 14 | ishigaki
# Processing Record 2 of Set 14 | ornskoldsvik
# Processing Record 3 of Set 14 | peleduy
# Processing Record 4 of Set 14 | wellington
# Processing Record 5 of Set 14 | deer lake
# Processing Record 6 of Set 14 | byron bay
# Processing Record 7 of Set 14 | santa fe
# Processing Record 8 of Set 14 | turka
# Processing Record 9 of Set 14 | okhotsk
# Processing Record 10 of Set 14 | erhlin
# City not found. Skipping...
# Processing Record 11 of Set 14 | srednekolymsk
# Processing Record 12 of Set 14 | geilo
# Processing Record 13 of Set 14 | marzuq
# Processing Record 14 of Set 14 | berezovo
# Processing Record 15 of Set 14 | rawson
# Processing Record 16 of Set 14 | darhan
# Processing Record 17 of Set 14 | pervomayskoye
# Processing Record 18 of Set 14 | port-cartier
# Processing Record 19 of Set 14 | arkhangelsk
# Processing Record 20 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 21 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 22 of Set 14 | isla vista
# Processing Record 23 of Set 14 | hami
# Processing Record 24 of Set 14 | rio grande
# Processing Record 25 of Set 14 | khash
# Processing Record 26 of Set 14 | marovoay
# Processing Record 27 of Set 14 | teluk nibung
# Processing Record 28 of Set 14 | kuching
# Processing Record 29 of Set 14 | chikoy
# City not found. Skipping...
# Processing Record 30 of Set 14 | otane
# Processing Record 31 of Set 14 | moose factory
# Processing Record 32 of Set 14 | santa cruz
# Processing Record 33 of Set 14 | half moon bay
# Processing Record 34 of Set 14 | maningrida
# Processing Record 35 of Set 14 | kearney
# Processing Record 36 of Set 14 | magaria
# Processing Record 37 of Set 14 | santiago de cao
# Processing Record 38 of Set 14 | aktash
# Processing Record 39 of Set 14 | tuy hoa
# Processing Record 40 of Set 14 | oistins
# Processing Record 41 of Set 14 | amberley
# Processing Record 42 of Set 14 | isabela
# Processing Record 43 of Set 14 | tateyama
# Processing Record 44 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 45 of Set 14 | sakaiminato
# Processing Record 46 of Set 14 | sarkand
# Processing Record 47 of Set 14 | palana
# Processing Record 48 of Set 14 | santa luzia
# Processing Record 49 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 50 of Set 14 | sakete
# Processing Record 1 of Set 15 | poltava
# Processing Record 2 of Set 15 | gannan
# Processing Record 3 of Set 15 | tabas
# Processing Record 4 of Set 15 | maumere
# Processing Record 5 of Set 15 | yamada
# Processing Record 6 of Set 15 | prince rupert
# Processing Record 7 of Set 15 | siderno
# Processing Record 8 of Set 15 | manokwari
# Processing Record 9 of Set 15 | ust-nera
# Processing Record 10 of Set 15 | husavik
# Processing Record 11 of Set 15 | staryy biser
# City not found. Skipping...
# Processing Record 12 of Set 15 | tshela
# Processing Record 13 of Set 15 | amga
# Processing Record 14 of Set 15 | luang prabang
# Processing Record 15 of Set 15 | edmundston
# Processing Record 16 of Set 15 | chumikan
# Processing Record 17 of Set 15 | sibolga
# Processing Record 18 of Set 15 | zhitikara
# City not found. Skipping...
# Processing Record 19 of Set 15 | phulpur
# Processing Record 20 of Set 15 | guangyuan
# Processing Record 21 of Set 15 | palaikastron
# Processing Record 22 of Set 15 | yanam
# Processing Record 23 of Set 15 | caska
# Processing Record 24 of Set 15 | pimentel
# Processing Record 25 of Set 15 | pitimbu
# Processing Record 26 of Set 15 | douentza
# Processing Record 27 of Set 15 | kotaparh
# Processing Record 28 of Set 15 | romita
# Processing Record 29 of Set 15 | arak
# Processing Record 30 of Set 15 | vao
# Processing Record 31 of Set 15 | rio verde de mato grosso
# Processing Record 32 of Set 15 | bairiki
# Processing Record 33 of Set 15 | dryden
# Processing Record 34 of Set 15 | maroantsetra
# Processing Record 35 of Set 15 | cuamba
# Processing Record 36 of Set 15 | porto-vecchio
# Processing Record 37 of Set 15 | nerchinskiy zavod
# Processing Record 38 of Set 15 | ostersund
# Processing Record 39 of Set 15 | dali
# Processing Record 40 of Set 15 | denpasar
# Processing Record 41 of Set 15 | houston
# Processing Record 42 of Set 15 | coronado
# Processing Record 43 of Set 15 | vanavara
# Processing Record 44 of Set 15 | tianpeng
# Processing Record 45 of Set 15 | san antonio
# Processing Record 46 of Set 15 | barra
# Processing Record 47 of Set 15 | chunskiy
# Processing Record 48 of Set 15 | yatou
# Processing Record 49 of Set 15 | codrington
# Processing Record 50 of Set 15 | tsiroanomandidy
# Processing Record 1 of Set 16 | igrim
# Processing Record 2 of Set 16 | nola
# Processing Record 3 of Set 16 | cabra
# Processing Record 4 of Set 16 | rocha
# -----------------------------
# Data Retrieval Complete

# %%
len(city_data)
# Out:
# 687

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weatherpy_database_df = pd.DataFrame(city_data)
weatherpy_database_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Vaini -21.2000 -175.2000     60.96        94          20
# 1  San Patricio  28.0170  -97.5169     84.09        60           5
# 2         Kapaa  22.0752 -159.3190     73.72        97          75
# 3       Almansa  38.8692   -1.0971     80.69        28         100
# 4     Bathsheba  13.2167  -59.5167     83.03        73          10
#
#    Wind Speed Country Current Description
# 0        5.75      TO          few clouds
# 1       10.16      US           clear sky
# 2       16.11      US       broken clouds
# 3       10.78      ES     overcast clouds
# 4       19.06      BB           clear sky

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness","Wind Speed", "Current Description"]
weatherpy_database_df = weatherpy_database_df[new_column_order]
weatherpy_database_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Vaini      TO -21.2000 -175.2000     60.96        94          20
# 1  San Patricio      US  28.0170  -97.5169     84.09        60           5
# 2         Kapaa      US  22.0752 -159.3190     73.72        97          75
# 3       Almansa      ES  38.8692   -1.0971     80.69        28         100
# 4     Bathsheba      BB  13.2167  -59.5167     83.03        73          10
# 5       Dudinka      RU  69.4058   86.1778     35.13       100         100
# 6       Laramie      US  41.3114 -105.5911     59.54        44           0
# 7       Xichang      CN  27.8964  102.2634     52.52        90         100
# 8      Tasiilaq      GL  65.6145  -37.6368     32.16        97         100
# 9      Victoria      HK  22.2855  114.1577     71.65        94         100
#
#    Wind Speed Current Description
# 0        5.75          few clouds
# 1       10.16           clear sky
# 2       16.11       broken clouds
# 3       10.78     overcast clouds
# 4       19.06           clear sky
# 5        5.97     overcast clouds
# 6       12.66           clear sky
# 7        1.14     overcast clouds
# 8       14.32                snow
# 9        5.01     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weatherpy_Database.csv"
# Export the City_Data into a CSV.
weatherpy_database_df.to_csv(output_data_file, index_label="City_ID")
